# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
from pickle import dump

# %% [markdown]
# ## With All Features standard typology

# %%
# Load training sets
X_train_scaled = pd.read_csv("test_train_data/X_train_scaled.csv")
X_train_scaled_sk = pd.read_csv("test_train_data/X_train_scaled_sk.csv")
X_train_scaled_cs = pd.read_csv("test_train_data/X_train_scaled_cs.csv")
y_train_categorical = pd.read_csv("test_train_data/y_train_categorical.csv")

# %%
# Load testing sets
X_test_scaled = pd.read_csv("test_train_data/X_test_scaled.csv")
X_test_scaled_sk = pd.read_csv("test_train_data/X_test_scaled_sk.csv")
X_test_scaled_cs = pd.read_csv("test_train_data/X_test_scaled_cs.csv")
y_test_categorical = pd.read_csv("test_train_data/y_test_categorical.csv")

# %%
deep_model = Sequential()
deep_model.add(Dense(units=90, activation='relu', input_dim=X_train_scaled.shape[1]))
deep_model.add(Dense(units=90, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
# Compile the model
deep_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
deep_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 90)                2790
# _________________________________________________________________
# dense_1 (Dense)              (None, 90)                8190
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 182
# =================================================================
# Total params: 11,162
# Trainable params: 11,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model to the training data without PCA
deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 14/14 - 0s - loss: 0.4253 - accuracy: 0.8282
# Epoch 2/100
# 14/14 - 0s - loss: 0.1644 - accuracy: 0.9459
# Epoch 3/100
# 14/14 - 0s - loss: 0.0986 - accuracy: 0.9741
# Epoch 4/100
# 14/14 - 0s - loss: 0.0746 - accuracy: 0.9859
# Epoch 5/100
# 14/14 - 0s - loss: 0.0634 - accuracy: 0.9812
# Epoch 6/100
# 14/14 - 0s - loss: 0.0562 - accuracy: 0.9859
# Epoch 7/100
# 14/14 - 0s - loss: 0.0493 - accuracy: 0.9882
# Epoch 8/100
# 14/14 - 0s - loss: 0.0435 - accuracy: 0.9882
# Epoch 9/100
# 14/14 - 0s - loss: 0.0394 - accuracy: 0.9929
# Epoch 10/100
# 14/14 - 0s - loss: 0.0354 - accuracy: 0.9929
# Epoch 11/100
# 14/14 - 0s - loss: 0.0326 - accuracy: 0.9929
# Epoch 12/100
# 14/14 - 0s - loss: 0.0305 - accuracy: 0.9953
# Epoch 13/100
# 14/14 - 0s - loss: 0.0268 - accuracy: 0.9929
# Epoch 14/100
# 14/14 - 0s - loss: 0.0235 - accuracy: 0.9929
# Epoch 15/100
# 14/14 - 0s - loss: 0.0216 - accuracy: 0.9929
# Epoch 16/100
# 14/14 - 0s - loss: 0.0182 - accuracy: 0.9953
# Epoch 17/100
# 14/14 - 0s - loss: 0.0164 - accuracy: 0.9929
# Epoch 18/100
# 14/14 - 0s - loss: 0.0139 - accuracy: 0.9953
# Epoch 19/100
# 14/14 - 0s - loss: 0.0125 - accuracy: 0.9976
# Epoch 20/100
# 14/14 - 0s - loss: 0.0110 - accuracy: 0.9976
# Epoch 21/100
# 14/14 - 0s - loss: 0.0096 - accuracy: 1.0000
# Epoch 22/100
# 14/14 - 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 23/100
# 14/14 - 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 24/100
# 14/14 - 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 25/100
# 14/14 - 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 26/100
# 14/14 - 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 27/100
# 14/14 - 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 28/100
# 14/14 - 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 29/100
# 14/14 - 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 30/100
# 14/14 - 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 31/100
# 14/14 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 32/100
# 14/14 - 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 33/100
# 14/14 - 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 34/100
# 14/14 - 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 35/100
# 14/14 - 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 36/100
# 14/14 - 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 37/100
# 14/14 - 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 38/100
# 14/14 - 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 39/100
# 14/14 - 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 40/100
# 14/14 - 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 41/100
# 14/14 - 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 42/100
# 14/14 - 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 43/100
# 14/14 - 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 44/100
# 14/14 - 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 45/100
# 14/14 - 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 46/100
# 14/14 - 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 47/100
# 14/14 - 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 48/100
# 14/14 - 0s - loss: 9.3137e-04 - accuracy: 1.0000
# Epoch 49/100
# 14/14 - 0s - loss: 9.0879e-04 - accuracy: 1.0000
# Epoch 50/100
# 14/14 - 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 51/100
# 14/14 - 0s - loss: 8.1136e-04 - accuracy: 1.0000
# Epoch 52/100
# 14/14 - 0s - loss: 7.7492e-04 - accuracy: 1.0000
# Epoch 53/100
# 14/14 - 0s - loss: 7.3679e-04 - accuracy: 1.0000
# Epoch 54/100
# 14/14 - 0s - loss: 6.8432e-04 - accuracy: 1.0000
# Epoch 55/100
# 14/14 - 0s - loss: 6.7767e-04 - accuracy: 1.0000
# Epoch 56/100
# 14/14 - 0s - loss: 6.2480e-04 - accuracy: 1.0000
# Epoch 57/100
# 14/14 - 0s - loss: 6.0002e-04 - accuracy: 1.0000
# Epoch 58/100
# 14/14 - 0s - loss: 5.6658e-04 - accuracy: 1.0000
# Epoch 59/100
# 14/14 - 0s - loss: 5.4061e-04 - accuracy: 1.0000
# Epoch 60/100
# 14/14 - 0s - loss: 5.1203e-04 - accuracy: 1.0000
# Epoch 61/100
# 14/14 - 0s - loss: 4.9949e-04 - accuracy: 1.0000
# Epoch 62/100
# 14/14 - 0s - loss: 4.7704e-04 - accuracy: 1.0000
# Epoch 63/100
# 14/14 - 0s - loss: 4.6725e-04 - accuracy: 1.0000
# Epoch 64/100
# 14/14 - 0s - loss: 4.3784e-04 - accuracy: 1.0000
# Epoch 65/100
# 14/14 - 0s - loss: 4.3088e-04 - accuracy: 1.0000
# Epoch 66/100
# 14/14 - 0s - loss: 4.1298e-04 - accuracy: 1.0000
# Epoch 67/100
# 14/14 - 0s - loss: 3.9533e-04 - accuracy: 1.0000
# Epoch 68/100
# 14/14 - 0s - loss: 3.8452e-04 - accuracy: 1.0000
# Epoch 69/100
# 14/14 - 0s - loss: 3.6955e-04 - accuracy: 1.0000
# Epoch 70/100
# 14/14 - 0s - loss: 3.5131e-04 - accuracy: 1.0000
# Epoch 71/100
# 14/14 - 0s - loss: 3.4192e-04 - accuracy: 1.0000
# Epoch 72/100
# 14/14 - 0s - loss: 3.2583e-04 - accuracy: 1.0000
# Epoch 73/100
# 14/14 - 0s - loss: 3.4306e-04 - accuracy: 1.0000
# Epoch 74/100
# 14/14 - 0s - loss: 3.0738e-04 - accuracy: 1.0000
# Epoch 75/100
# 14/14 - 0s - loss: 3.1027e-04 - accuracy: 1.0000
# Epoch 76/100
# 14/14 - 0s - loss: 3.0098e-04 - accuracy: 1.0000
# Epoch 77/100
# 14/14 - 0s - loss: 2.9237e-04 - accuracy: 1.0000
# Epoch 78/100
# 14/14 - 0s - loss: 2.7545e-04 - accuracy: 1.0000
# Epoch 79/100
# 14/14 - 0s - loss: 2.5634e-04 - accuracy: 1.0000
# Epoch 80/100
# 14/14 - 0s - loss: 2.4488e-04 - accuracy: 1.0000
# Epoch 81/100
# 14/14 - 0s - loss: 2.4645e-04 - accuracy: 1.0000
# Epoch 82/100
# 14/14 - 0s - loss: 2.3186e-04 - accuracy: 1.0000
# Epoch 83/100
# 14/14 - 0s - loss: 2.2649e-04 - accuracy: 1.0000
# Epoch 84/100
# 14/14 - 0s - loss: 2.1673e-04 - accuracy: 1.0000
# Epoch 85/100
# 14/14 - 0s - loss: 2.1204e-04 - accuracy: 1.0000
# Epoch 86/100
# 14/14 - 0s - loss: 2.1073e-04 - accuracy: 1.0000
# Epoch 87/100
# 14/14 - 0s - loss: 1.9971e-04 - accuracy: 1.0000
# Epoch 88/100
# 14/14 - 0s - loss: 1.9567e-04 - accuracy: 1.0000
# Epoch 89/100
# 14/14 - 0s - loss: 1.8478e-04 - accuracy: 1.0000
# Epoch 90/100
# 14/14 - 0s - loss: 1.7684e-04 - accuracy: 1.0000
# Epoch 91/100
# 14/14 - 0s - loss: 1.7480e-04 - accuracy: 1.0000
# Epoch 92/100
# 14/14 - 0s - loss: 1.6789e-04 - accuracy: 1.0000
# Epoch 93/100
# 14/14 - 0s - loss: 1.6412e-04 - accuracy: 1.0000
# Epoch 94/100
# 14/14 - 0s - loss: 1.5975e-04 - accuracy: 1.0000
# Epoch 95/100
# 14/14 - 0s - loss: 1.5682e-04 - accuracy: 1.0000
# Epoch 96/100
# 14/14 - 0s - loss: 1.5306e-04 - accuracy: 1.0000
# Epoch 97/100
# 14/14 - 0s - loss: 1.4728e-04 - accuracy: 1.0000
# Epoch 98/100
# 14/14 - 0s - loss: 1.4867e-04 - accuracy: 1.0000
# Epoch 99/100
# 14/14 - 0s - loss: 1.4037e-04 - accuracy: 1.0000
# Epoch 100/100
# 14/14 - 0s - loss: 1.3875e-04 - accuracy: 1.0000

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 5/5 - 0s - loss: 0.1084 - accuracy: 0.9789
# Deep Neural Network - Loss: 0.10840298980474472, Accuracy: 0.9788732528686523

# %%
# # For Label comparison
# label_encoder = LabelEncoder()
# y_train_categorical = y_train_categorical.to_numpy()
# y_train_categorical = y_train_categorical.ravel()
# label_encoder.fit(y_train_categorical)
# encoded_predictions = deep_model.predict_classes(X_test_scaled[:10])
# prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# prediction_labels = np.where((prediction_labels == 0), "B", "M")
# print(f"Predicted classes: {prediction_labels}")
# print(f"Actual Labels: {list(y_test_categorical[:10])}")

# %% [markdown]
# ## With SelectKBest selected Features

# %%
deep_model_sk = Sequential()
deep_model_sk.add(Dense(units=30, activation='relu', input_dim=X_train_scaled_sk.shape[1]))
deep_model_sk.add(Dense(units=30, activation='relu'))
deep_model_sk.add(Dense(units=2, activation='softmax'))

# %%
# Compile the model
deep_model_sk.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
deep_model_sk.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 30)                240
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 62
# =================================================================
# Total params: 1,232
# Trainable params: 1,232
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model to the training data with SK
deep_model_sk.fit(
    X_train_scaled_sk,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 14/14 - 0s - loss: 0.5757 - accuracy: 0.9059
# Epoch 2/100
# 14/14 - 0s - loss: 0.4032 - accuracy: 0.9294
# Epoch 3/100
# 14/14 - 0s - loss: 0.3036 - accuracy: 0.9271
# Epoch 4/100
# 14/14 - 0s - loss: 0.2422 - accuracy: 0.9271
# Epoch 5/100
# 14/14 - 0s - loss: 0.2072 - accuracy: 0.9318
# Epoch 6/100
# 14/14 - 0s - loss: 0.1870 - accuracy: 0.9318
# Epoch 7/100
# 14/14 - 0s - loss: 0.1737 - accuracy: 0.9318
# Epoch 8/100
# 14/14 - 0s - loss: 0.1660 - accuracy: 0.9318
# Epoch 9/100
# 14/14 - 0s - loss: 0.1604 - accuracy: 0.9365
# Epoch 10/100
# 14/14 - 0s - loss: 0.1563 - accuracy: 0.9412
# Epoch 11/100
# 14/14 - 0s - loss: 0.1526 - accuracy: 0.9412
# Epoch 12/100
# 14/14 - 0s - loss: 0.1502 - accuracy: 0.9412
# Epoch 13/100
# 14/14 - 0s - loss: 0.1477 - accuracy: 0.9435
# Epoch 14/100
# 14/14 - 0s - loss: 0.1452 - accuracy: 0.9459
# Epoch 15/100
# 14/14 - 0s - loss: 0.1428 - accuracy: 0.9459
# Epoch 16/100
# 14/14 - 0s - loss: 0.1406 - accuracy: 0.9412
# Epoch 17/100
# 14/14 - 0s - loss: 0.1389 - accuracy: 0.9435
# Epoch 18/100
# 14/14 - 0s - loss: 0.1365 - accuracy: 0.9412
# Epoch 19/100
# 14/14 - 0s - loss: 0.1347 - accuracy: 0.9388
# Epoch 20/100
# 14/14 - 0s - loss: 0.1332 - accuracy: 0.9388
# Epoch 21/100
# 14/14 - 0s - loss: 0.1314 - accuracy: 0.9435
# Epoch 22/100
# 14/14 - 0s - loss: 0.1297 - accuracy: 0.9459
# Epoch 23/100
# 14/14 - 0s - loss: 0.1280 - accuracy: 0.9435
# Epoch 24/100
# 14/14 - 0s - loss: 0.1263 - accuracy: 0.9482
# Epoch 25/100
# 14/14 - 0s - loss: 0.1256 - accuracy: 0.9529
# Epoch 26/100
# 14/14 - 0s - loss: 0.1240 - accuracy: 0.9529
# Epoch 27/100
# 14/14 - 0s - loss: 0.1230 - accuracy: 0.9529
# Epoch 28/100
# 14/14 - 0s - loss: 0.1216 - accuracy: 0.9529
# Epoch 29/100
# 14/14 - 0s - loss: 0.1198 - accuracy: 0.9576
# Epoch 30/100
# 14/14 - 0s - loss: 0.1185 - accuracy: 0.9553
# Epoch 31/100
# 14/14 - 0s - loss: 0.1177 - accuracy: 0.9600
# Epoch 32/100
# 14/14 - 0s - loss: 0.1160 - accuracy: 0.9600
# Epoch 33/100
# 14/14 - 0s - loss: 0.1156 - accuracy: 0.9576
# Epoch 34/100
# 14/14 - 0s - loss: 0.1153 - accuracy: 0.9600
# Epoch 35/100
# 14/14 - 0s - loss: 0.1141 - accuracy: 0.9600
# Epoch 36/100
# 14/14 - 0s - loss: 0.1130 - accuracy: 0.9576
# Epoch 37/100
# 14/14 - 0s - loss: 0.1117 - accuracy: 0.9600
# Epoch 38/100
# 14/14 - 0s - loss: 0.1108 - accuracy: 0.9600
# Epoch 39/100
# 14/14 - 0s - loss: 0.1107 - accuracy: 0.9576
# Epoch 40/100
# 14/14 - 0s - loss: 0.1103 - accuracy: 0.9600
# Epoch 41/100
# 14/14 - 0s - loss: 0.1095 - accuracy: 0.9600
# Epoch 42/100
# 14/14 - 0s - loss: 0.1086 - accuracy: 0.9624
# Epoch 43/100
# 14/14 - 0s - loss: 0.1076 - accuracy: 0.9624
# Epoch 44/100
# 14/14 - 0s - loss: 0.1074 - accuracy: 0.9624
# Epoch 45/100
# 14/14 - 0s - loss: 0.1072 - accuracy: 0.9600
# Epoch 46/100
# 14/14 - 0s - loss: 0.1073 - accuracy: 0.9647
# Epoch 47/100
# 14/14 - 0s - loss: 0.1065 - accuracy: 0.9624
# Epoch 48/100
# 14/14 - 0s - loss: 0.1062 - accuracy: 0.9647
# Epoch 49/100
# 14/14 - 0s - loss: 0.1058 - accuracy: 0.9624
# Epoch 50/100
# 14/14 - 0s - loss: 0.1050 - accuracy: 0.9624
# Epoch 51/100
# 14/14 - 0s - loss: 0.1045 - accuracy: 0.9647
# Epoch 52/100
# 14/14 - 0s - loss: 0.1043 - accuracy: 0.9647
# Epoch 53/100
# 14/14 - 0s - loss: 0.1040 - accuracy: 0.9647
# Epoch 54/100
# 14/14 - 0s - loss: 0.1036 - accuracy: 0.9647
# Epoch 55/100
# 14/14 - 0s - loss: 0.1035 - accuracy: 0.9624
# Epoch 56/100
# 14/14 - 0s - loss: 0.1024 - accuracy: 0.9647
# Epoch 57/100
# 14/14 - 0s - loss: 0.1022 - accuracy: 0.9671
# Epoch 58/100
# 14/14 - 0s - loss: 0.1022 - accuracy: 0.9671
# Epoch 59/100
# 14/14 - 0s - loss: 0.1015 - accuracy: 0.9647
# Epoch 60/100
# 14/14 - 0s - loss: 0.1012 - accuracy: 0.9647
# Epoch 61/100
# 14/14 - 0s - loss: 0.1007 - accuracy: 0.9647
# Epoch 62/100
# 14/14 - 0s - loss: 0.1002 - accuracy: 0.9647
# Epoch 63/100
# 14/14 - 0s - loss: 0.1000 - accuracy: 0.9647
# Epoch 64/100
# 14/14 - 0s - loss: 0.0998 - accuracy: 0.9624
# Epoch 65/100
# 14/14 - 0s - loss: 0.1007 - accuracy: 0.9624
# Epoch 66/100
# 14/14 - 0s - loss: 0.0992 - accuracy: 0.9624
# Epoch 67/100
# 14/14 - 0s - loss: 0.0990 - accuracy: 0.9647
# Epoch 68/100
# 14/14 - 0s - loss: 0.0988 - accuracy: 0.9647
# Epoch 69/100
# 14/14 - 0s - loss: 0.0990 - accuracy: 0.9647
# Epoch 70/100
# 14/14 - 0s - loss: 0.0982 - accuracy: 0.9647
# Epoch 71/100
# 14/14 - 0s - loss: 0.0997 - accuracy: 0.9600
# Epoch 72/100
# 14/14 - 0s - loss: 0.0976 - accuracy: 0.9647
# Epoch 73/100
# 14/14 - 0s - loss: 0.0973 - accuracy: 0.9647
# Epoch 74/100
# 14/14 - 0s - loss: 0.0967 - accuracy: 0.9647
# Epoch 75/100
# 14/14 - 0s - loss: 0.0972 - accuracy: 0.9694
# Epoch 76/100
# 14/14 - 0s - loss: 0.0956 - accuracy: 0.9671
# Epoch 77/100
# 14/14 - 0s - loss: 0.0966 - accuracy: 0.9647
# Epoch 78/100
# 14/14 - 0s - loss: 0.0964 - accuracy: 0.9671
# Epoch 79/100
# 14/14 - 0s - loss: 0.0949 - accuracy: 0.9671
# Epoch 80/100
# 14/14 - 0s - loss: 0.0951 - accuracy: 0.9647
# Epoch 81/100
# 14/14 - 0s - loss: 0.0952 - accuracy: 0.9671
# Epoch 82/100
# 14/14 - 0s - loss: 0.0945 - accuracy: 0.9671
# Epoch 83/100
# 14/14 - 0s - loss: 0.0944 - accuracy: 0.9694
# Epoch 84/100
# 14/14 - 0s - loss: 0.0930 - accuracy: 0.9671
# Epoch 85/100
# 14/14 - 0s - loss: 0.0939 - accuracy: 0.9647
# Epoch 86/100
# 14/14 - 0s - loss: 0.0942 - accuracy: 0.9671
# Epoch 87/100
# 14/14 - 0s - loss: 0.0935 - accuracy: 0.9671
# Epoch 88/100
# 14/14 - 0s - loss: 0.0931 - accuracy: 0.9647
# Epoch 89/100
# 14/14 - 0s - loss: 0.0932 - accuracy: 0.9647
# Epoch 90/100
# 14/14 - 0s - loss: 0.0925 - accuracy: 0.9671
# Epoch 91/100
# 14/14 - 0s - loss: 0.0920 - accuracy: 0.9671
# Epoch 92/100
# 14/14 - 0s - loss: 0.0922 - accuracy: 0.9647
# Epoch 93/100
# 14/14 - 0s - loss: 0.0922 - accuracy: 0.9718
# Epoch 94/100
# 14/14 - 0s - loss: 0.0920 - accuracy: 0.9718
# Epoch 95/100
# 14/14 - 0s - loss: 0.0918 - accuracy: 0.9694
# Epoch 96/100
# 14/14 - 0s - loss: 0.0916 - accuracy: 0.9694
# Epoch 97/100
# 14/14 - 0s - loss: 0.0926 - accuracy: 0.9694
# Epoch 98/100
# 14/14 - 0s - loss: 0.0899 - accuracy: 0.9718
# Epoch 99/100
# 14/14 - 0s - loss: 0.0911 - accuracy: 0.9694
# Epoch 100/100
# 14/14 - 0s - loss: 0.0914 - accuracy: 0.9718

# %%
model_loss, model_accuracy = deep_model_sk.evaluate(
    X_test_scaled_sk, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 5/5 - 0s - loss: 0.0852 - accuracy: 0.9718
# Deep Neural Network - Loss: 0.08523042500019073, Accuracy: 0.9718309640884399

# %% [markdown]
# ## With Correlation-based selected Features

# %%
deep_model_cs = Sequential()
deep_model_cs.add(Dense(units=30, activation='relu', input_dim=X_train_scaled_cs.shape[1]))
deep_model_cs.add(Dense(units=30, activation='relu'))
deep_model_cs.add(Dense(units=2, activation='softmax'))

# %%
# Compile the model
deep_model_cs.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
deep_model_cs.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 30)                240
# _________________________________________________________________
# dense_7 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 62
# =================================================================
# Total params: 1,232
# Trainable params: 1,232
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model to the training data with PCA
deep_model_cs.fit(
    X_train_scaled_cs,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 14/14 - 0s - loss: 0.7154 - accuracy: 0.6259
# Epoch 2/100
# 14/14 - 0s - loss: 0.5586 - accuracy: 0.7741
# Epoch 3/100
# 14/14 - 0s - loss: 0.4548 - accuracy: 0.8353
# Epoch 4/100
# 14/14 - 0s - loss: 0.3690 - accuracy: 0.8753
# Epoch 5/100
# 14/14 - 0s - loss: 0.3029 - accuracy: 0.8988
# Epoch 6/100
# 14/14 - 0s - loss: 0.2528 - accuracy: 0.9176
# Epoch 7/100
# 14/14 - 0s - loss: 0.2158 - accuracy: 0.9271
# Epoch 8/100
# 14/14 - 0s - loss: 0.1869 - accuracy: 0.9412
# Epoch 9/100
# 14/14 - 0s - loss: 0.1652 - accuracy: 0.9435
# Epoch 10/100
# 14/14 - 0s - loss: 0.1479 - accuracy: 0.9576
# Epoch 11/100
# 14/14 - 0s - loss: 0.1352 - accuracy: 0.9600
# Epoch 12/100
# 14/14 - 0s - loss: 0.1256 - accuracy: 0.9576
# Epoch 13/100
# 14/14 - 0s - loss: 0.1166 - accuracy: 0.9671
# Epoch 14/100
# 14/14 - 0s - loss: 0.1089 - accuracy: 0.9671
# Epoch 15/100
# 14/14 - 0s - loss: 0.1029 - accuracy: 0.9694
# Epoch 16/100
# 14/14 - 0s - loss: 0.0978 - accuracy: 0.9694
# Epoch 17/100
# 14/14 - 0s - loss: 0.0936 - accuracy: 0.9718
# Epoch 18/100
# 14/14 - 0s - loss: 0.0897 - accuracy: 0.9741
# Epoch 19/100
# 14/14 - 0s - loss: 0.0870 - accuracy: 0.9765
# Epoch 20/100
# 14/14 - 0s - loss: 0.0835 - accuracy: 0.9788
# Epoch 21/100
# 14/14 - 0s - loss: 0.0813 - accuracy: 0.9788
# Epoch 22/100
# 14/14 - 0s - loss: 0.0788 - accuracy: 0.9812
# Epoch 23/100
# 14/14 - 0s - loss: 0.0767 - accuracy: 0.9812
# Epoch 24/100
# 14/14 - 0s - loss: 0.0746 - accuracy: 0.9812
# Epoch 25/100
# 14/14 - 0s - loss: 0.0731 - accuracy: 0.9812
# Epoch 26/100
# 14/14 - 0s - loss: 0.0721 - accuracy: 0.9812
# Epoch 27/100
# 14/14 - 0s - loss: 0.0692 - accuracy: 0.9812
# Epoch 28/100
# 14/14 - 0s - loss: 0.0681 - accuracy: 0.9812
# Epoch 29/100
# 14/14 - 0s - loss: 0.0670 - accuracy: 0.9812
# Epoch 30/100
# 14/14 - 0s - loss: 0.0660 - accuracy: 0.9812
# Epoch 31/100
# 14/14 - 0s - loss: 0.0648 - accuracy: 0.9812
# Epoch 32/100
# 14/14 - 0s - loss: 0.0634 - accuracy: 0.9812
# Epoch 33/100
# 14/14 - 0s - loss: 0.0628 - accuracy: 0.9812
# Epoch 34/100
# 14/14 - 0s - loss: 0.0621 - accuracy: 0.9812
# Epoch 35/100
# 14/14 - 0s - loss: 0.0609 - accuracy: 0.9812
# Epoch 36/100
# 14/14 - 0s - loss: 0.0607 - accuracy: 0.9812
# Epoch 37/100
# 14/14 - 0s - loss: 0.0597 - accuracy: 0.9812
# Epoch 38/100
# 14/14 - 0s - loss: 0.0597 - accuracy: 0.9812
# Epoch 39/100
# 14/14 - 0s - loss: 0.0581 - accuracy: 0.9812
# Epoch 40/100
# 14/14 - 0s - loss: 0.0584 - accuracy: 0.9812
# Epoch 41/100
# 14/14 - 0s - loss: 0.0578 - accuracy: 0.9859
# Epoch 42/100
# 14/14 - 0s - loss: 0.0558 - accuracy: 0.9835
# Epoch 43/100
# 14/14 - 0s - loss: 0.0563 - accuracy: 0.9835
# Epoch 44/100
# 14/14 - 0s - loss: 0.0545 - accuracy: 0.9859
# Epoch 45/100
# 14/14 - 0s - loss: 0.0541 - accuracy: 0.9835
# Epoch 46/100
# 14/14 - 0s - loss: 0.0541 - accuracy: 0.9835
# Epoch 47/100
# 14/14 - 0s - loss: 0.0528 - accuracy: 0.9835
# Epoch 48/100
# 14/14 - 0s - loss: 0.0523 - accuracy: 0.9859
# Epoch 49/100
# 14/14 - 0s - loss: 0.0519 - accuracy: 0.9859
# Epoch 50/100
# 14/14 - 0s - loss: 0.0511 - accuracy: 0.9859
# Epoch 51/100
# 14/14 - 0s - loss: 0.0503 - accuracy: 0.9859
# Epoch 52/100
# 14/14 - 0s - loss: 0.0499 - accuracy: 0.9859
# Epoch 53/100
# 14/14 - 0s - loss: 0.0499 - accuracy: 0.9859
# Epoch 54/100
# 14/14 - 0s - loss: 0.0489 - accuracy: 0.9859
# Epoch 55/100
# 14/14 - 0s - loss: 0.0483 - accuracy: 0.9859
# Epoch 56/100
# 14/14 - 0s - loss: 0.0482 - accuracy: 0.9859
# Epoch 57/100
# 14/14 - 0s - loss: 0.0473 - accuracy: 0.9859
# Epoch 58/100
# 14/14 - 0s - loss: 0.0472 - accuracy: 0.9859
# Epoch 59/100
# 14/14 - 0s - loss: 0.0466 - accuracy: 0.9882
# Epoch 60/100
# 14/14 - 0s - loss: 0.0463 - accuracy: 0.9859
# Epoch 61/100
# 14/14 - 0s - loss: 0.0465 - accuracy: 0.9882
# Epoch 62/100
# 14/14 - 0s - loss: 0.0459 - accuracy: 0.9859
# Epoch 63/100
# 14/14 - 0s - loss: 0.0449 - accuracy: 0.9859
# Epoch 64/100
# 14/14 - 0s - loss: 0.0446 - accuracy: 0.9859
# Epoch 65/100
# 14/14 - 0s - loss: 0.0442 - accuracy: 0.9882
# Epoch 66/100
# 14/14 - 0s - loss: 0.0440 - accuracy: 0.9882
# Epoch 67/100
# 14/14 - 0s - loss: 0.0437 - accuracy: 0.9882
# Epoch 68/100
# 14/14 - 0s - loss: 0.0426 - accuracy: 0.9859
# Epoch 69/100
# 14/14 - 0s - loss: 0.0427 - accuracy: 0.9882
# Epoch 70/100
# 14/14 - 0s - loss: 0.0423 - accuracy: 0.9859
# Epoch 71/100
# 14/14 - 0s - loss: 0.0422 - accuracy: 0.9859
# Epoch 72/100
# 14/14 - 0s - loss: 0.0412 - accuracy: 0.9882
# Epoch 73/100
# 14/14 - 0s - loss: 0.0412 - accuracy: 0.9859
# Epoch 74/100
# 14/14 - 0s - loss: 0.0408 - accuracy: 0.9906
# Epoch 75/100
# 14/14 - 0s - loss: 0.0416 - accuracy: 0.9906
# Epoch 76/100
# 14/14 - 0s - loss: 0.0420 - accuracy: 0.9906
# Epoch 77/100
# 14/14 - 0s - loss: 0.0395 - accuracy: 0.9859
# Epoch 78/100
# 14/14 - 0s - loss: 0.0388 - accuracy: 0.9859
# Epoch 79/100
# 14/14 - 0s - loss: 0.0385 - accuracy: 0.9882
# Epoch 80/100
# 14/14 - 0s - loss: 0.0382 - accuracy: 0.9882
# Epoch 81/100
# 14/14 - 0s - loss: 0.0383 - accuracy: 0.9882
# Epoch 82/100
# 14/14 - 0s - loss: 0.0394 - accuracy: 0.9835
# Epoch 83/100
# 14/14 - 0s - loss: 0.0380 - accuracy: 0.9859
# Epoch 84/100
# 14/14 - 0s - loss: 0.0375 - accuracy: 0.9906
# Epoch 85/100
# 14/14 - 0s - loss: 0.0365 - accuracy: 0.9906
# Epoch 86/100
# 14/14 - 0s - loss: 0.0370 - accuracy: 0.9882
# Epoch 87/100
# 14/14 - 0s - loss: 0.0359 - accuracy: 0.9882
# Epoch 88/100
# 14/14 - 0s - loss: 0.0356 - accuracy: 0.9882
# Epoch 89/100
# 14/14 - 0s - loss: 0.0354 - accuracy: 0.9859
# Epoch 90/100
# 14/14 - 0s - loss: 0.0386 - accuracy: 0.9859
# Epoch 91/100
# 14/14 - 0s - loss: 0.0354 - accuracy: 0.9906
# Epoch 92/100
# 14/14 - 0s - loss: 0.0345 - accuracy: 0.9929
# Epoch 93/100
# 14/14 - 0s - loss: 0.0336 - accuracy: 0.9906
# Epoch 94/100
# 14/14 - 0s - loss: 0.0339 - accuracy: 0.9906
# Epoch 95/100
# 14/14 - 0s - loss: 0.0330 - accuracy: 0.9882
# Epoch 96/100
# 14/14 - 0s - loss: 0.0337 - accuracy: 0.9882
# Epoch 97/100
# 14/14 - 0s - loss: 0.0323 - accuracy: 0.9882
# Epoch 98/100
# 14/14 - 0s - loss: 0.0323 - accuracy: 0.9906
# Epoch 99/100
# 14/14 - 0s - loss: 0.0318 - accuracy: 0.9906
# Epoch 100/100
# 14/14 - 0s - loss: 0.0315 - accuracy: 0.9929

# %%
model_loss, model_accuracy = deep_model_cs.evaluate(
    X_test_scaled_cs, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 5/5 - 0s - loss: 0.1207 - accuracy: 0.9648
# Deep Neural Network - Loss: 0.12073930352926254, Accuracy: 0.9647887349128723

# %% [markdown]
# ## Try out AdaGrad

# %%
# deep_model_adagrad = Sequential()
# deep_model_adagrad.add(Dense(units=90, activation='relu', input_dim=X_train_scaled.shape[1]))
# deep_model_adagrad.add(Dense(units=90, activation='relu'))
# deep_model_adagrad.add(Dense(units=2, activation='softmax'))

# %%
# # Code for mini branch gradient descent
# deep_model_adagrad.compile(optimizer='adagrad',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])

# %%
# deep_model_adagrad.summary()

# %%
# deep_model_adagrad.fit(
#     X_train_scaled,
#     y_train_categorical,
#     epochs=100,
#     shuffle=True,
#     verbose=2
# )

# %%
# Save the best model
deep_model.save("pickles/deep_model_trained_all.h5")
deep_model_sk.save("pickles/deep_model_trained_sk.h5")
deep_model_cs.save("pickles/deep_model_trained_cs.h5")
